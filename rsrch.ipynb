# %% [markdown]
# # Тестовое задание для RSRCH

# %% [markdown]
# Задание: https://docs.google.com/document/d/1V66EmFAEiYz36Gvqv3IySPEuoNzmdqbn_pbPv-g4K7g/edit?usp=sharing

# %%
import pandas as pd
import numpy as np
import pymorphy2
import scipy.sparse as sparse

morph = pymorphy2.MorphAnalyzer()

from lightfm import LightFM

# %% [markdown]
# Для выполнения задания будем использовать файл с трудовыми действиями (`LaborAction.csv`) и описание курсов `teach-in.ru`. Можно использовать и другие источники данных, при этом подход к выполнению задания останется прежним.

# %% [markdown]
# Импортируем данные для трудовых действий

# %%
df_lab_actions = pd.read_csv('LaborAction.csv', sep=';', header=None)
df_lab_actions
# Out:
#                                                         0  \
# 0       Разработка и реализация программ учебных дисци...
# 1       Осуществление профессиональной деятельности в ...
# 2       Участие в разработке и реализации программы ра...
# 3               Планирование и проведение учебных занятий
# 4       Систематический анализ эффективности учебных з...
# ...                                                   ...
# 131304  Исправление ошибок в программном коде модулей ...
# 131305  Проведение тестирования программного обеспечен...
# 131306  Сбор результатов тестирования программного обе...
# 131307  Оценка соответствия результатов тестирования п...
# 131308  Оформление протоколов тестирования программног...
#
#                                        1
# 0       a347061b8b252e3a09a78d81c6d9fb82
# 1       a347061b8b252e3a09a78d81c6d9fb82
# 2       a347061b8b252e3a09a78d81c6d9fb82
# 3       a347061b8b252e3a09a78d81c6d9fb82
# 4       a347061b8b252e3a09a78d81c6d9fb82
# ...                                  ...
# 131304  d550e3377b1e2575b8f4045bc8703913
# 131305  d2c2de43d3b48430a1b43967e0b68d85
# 131306  d2c2de43d3b48430a1b43967e0b68d85
# 131307  d2c2de43d3b48430a1b43967e0b68d85
# 131308  d2c2de43d3b48430a1b43967e0b68d85
#
# [131309 rows x 2 columns]

# %% [markdown]
# Создадим вспомогательную функцию, которая будет создавать из строк трудовых действий список ключевых слов - существительных в единственном числе именительном падаже

# %%
def get_keys(value):
    keys = []
    for s in '1234567890-.,:;-?!\"': # удаляем не информативные символы из строки
        value = value.replace(s, ' ')
    for word in value.split(' '): # делим строку на слова
        p = morph.parse(word)[0] # для каждого слова выбираем разбор с максимальной вероятностью
        word_norm_form = p.normal_form # выделяем начальную форму слова
        if 'NOUN' in p.tag and word_norm_form not in keys: # если слово существительное и еще не было включено в список, включаем
            keys.append(word_norm_form)
    return keys

# %% [markdown]
# Также создадим аналогичную функцию, которая будет создавать список ключевых слов из серии трудовых действий

# %%
def get_keys_list(series):
    keys_list = []
    for value in series:
        for s in '1234567890-.,:;-?!\"':
            value = value.replace(s, ' ')
        for word in value.split(' '):
            p = morph.parse(word)[0]
            word_norm_form = p.normal_form
            if 'NOUN' in p.tag and word_norm_form not in keys_list:
                keys_list.append(word_norm_form)
    return keys_list

# %% [markdown]
# Создадим список ключевых слов из трудовых действий из `LaborAction.csv`

# %%
lab_actions_keys = get_keys_list(df_lab_actions[0])
lab_actions_keys
# Out:
# ['разработка',
#  'реализация',
#  'программа',
#  'дисциплина',
#  'рамка',
#  'осуществление',
#  'деятельность',
#  'соответствие',
#  'требование',
#  'стандарт',
#  'среднее',
#  'образование',
#  'участие',
#  'развитие',
#  'организация',
#  'цель',
#  'создание',
#  'среда',
#  'планирование',
#  'проведение',
#  'занятие',
#  'анализ',
#  'эффективность',
#  'подход',
#  'обучение',
#  'контроль',
#  'оценка',
#  'достижение',
#  'результат',
#  'освоение',
#  'формирование',
#  'действие',
#  'навык',
#  'технология',
#  'мотивация',
#  'знание',
#  'основа',
#  'тестирование',
#  'метод',
#  'возможность',
#  'ребёнок',
#  'регулирование',
#  'поведение',
#  'обеспечение',
#  'число',
#  'форма',
#  'работа',
#  'постановка',
#  'способность',
#  'характер',
#  'определение',
#  'принятие',
#  'правило',
#  'устав',
#  'распорядок',
#  'проектирование',
#  'вид',
#  'ситуация',
#  'событие',
#  'сфера',
#  '(культура',
#  'переживание',
#  'ориентация',
#  'помощь',
#  'поддержка',
#  'орган',
#  'самоуправление',
#  'поддержание',
#  'уклад',
#  'атмосфера',
#  'традиция',
#  'жизнь',
#  'активность',
#  'самостоятельность',
#  'инициатива',
#  'позиция',
#  'труд',
#  'условие',
#  'мир',
#  'культура',
#  'образ',
#  'толерантность',
#  'использование',
#  'усилие',
#  'родитель',
#  'семья',
#  'решение',
#  'вопрос',
#  'воспитание',
#  'выявление',
#  'ход',
#  'наблюдение',
#  'проблема',
#  'особенность',
#  'параметр',
#  'профилактика',
#  'насилие',
#  'школа',
#  'применение',
#  'инструментарий',
#  'диагностика',
#  'показатель',
#  'уровень',
#  'динамика',
#  'психолого',
#  'контингент',
#  'мигрант',
#  'сирота',
#  'потребность',
#  '(аутист',
#  'синдром',
#  'дефицит',
#  'внимание',
#  'гиперактивность',
#  'др',
#  'здоровье',
#  'девиация',
#  'зависимость',
#  'оказание',
#  'взаимодействие',
#  'специалист',
#  'консилиум',
#  'образец',
#  'ценность',
#  'реальность',
#  'сеть',
#  'общение',
#  'система',
#  'регуляция',
#  'безопасность',
#  'благополучие',
#  'период',
#  'пребывание',
#  'группа',
#  'возраст',
#  'мониторинг',
#  'корректировка',
#  'задача',
#  'психолог',
#  'учёт',
#  'рекомендация',
#  '(психолог',
#  'логопед',
#  'дефектолог',
#  'трудность',
#  'компетенция',
#  'готовность',
#  'климат',
#  'отношение',
#  'общность',
#  'слой',
#  'игра',
#  'конструирование',
#  'время',
#  'пространство',
#  'выбор',
#  'участник',
#  'материал',
#  'процесс',
#  'первоклассник',
#  'связь',
#  'переход',
#  'протяжение',
#  'умение',
#  'успех',
#  'неравномерность',
#  'своеобразие',
#  'мальчик',
#  'девочка',
#  'данные',
#  'сила',
#  'различие',
#  'класс',
#  'мероприятие',
#  'адаптация',
#  'понимание',
#  'место',
#  'предмет',
#  'картина',
#  'способ',
#  '(педагог',
#  'учитель',
#  'методист',
#  'зона',
#  'маршрут',
#  'специфика',
#  'состав',
#  'уточнение',
#  'модификация',
#  'повышение',
#  'источник',
#  'информация',
#  'инструмент',
#  'перевод',
#  'произношение',
#  'олимпиада',
#  'конференция',
#  'турнир',
#  'рассуждение',
#  'коммуникация',
#  'установка',
#  'постижение',
#  'модель',
#  'объект',
#  'моделирование',
#  'построение',
#  'предсказание',
#  'свойство',
#  'область',
#  'математика',
#  'информатика',
#  'доказательство',
#  'пример',
#  'подзадача',
#  'вариант',
#  'частность',
#  'формула',
#  'конфигурация',
#  'алгоритм',
#  '(например',
#  'принцип',
#  'педагогика',
#  'средство',
#  'уважение',
#  'сотрудничество',
#  'физика',
#  'экономика',
#  'язык',
#  'элемент',
#  'ресурс',
#  'содействие',
#  'подготовка',
#  'конкурс',
#  'проект',
#  'марафон',
#  'предоставление',
#  'задание',
#  'ведение',
#  'кружок',
#  'курс',
#  'изучение',
#  'консультирование',
#  'профессия',
#  'специальность',
#  'эмоция',
#  'нахождение',
#  'ошибка',
#  'улучшение',
#  'сторона',
#  'одноклассник',
#  'представление',
#  'полезность',
#  'диалог',
#  'подтверждение',
#  'правильность',
#  'сообщение',
#  'структуризация',
#  'реорганизация',
#  'трансформация',
#  'сопоставление',
#  'поиск',
#  'обсуждение',
#  'изменение',
#  'реакция',
#  'социум',
#  '«чувство',
#  'отличие',
#  'дискуссия',
#  'разрешение',
#  'выступление',
#  'поощрение',
#  'дебаты',
#  'форум',
#  'интернет',
#  'контекст',
#  'гипермедиа',
#  'формат',
#  'стимулирование',
#  '(рассказ',
#  'поездка',
#  'спектакль',
#  'п',
#  'структура',
#  'произведение',
#  'проза',
#  'журналистика',
#  'реклама',
#  'творчество',
#  'видеопродукт',
#  'компетентность',
#  'качество',
#  'работник',
#  '(издание',
#  'газета',
#  'альманах',
#  'радио',
#  'телевидение',
#  'сценарий',
#  'видеофильм',
#  'практика',
#  'речь',
#  'норма',
#  'ссылка',
#  'опубликование',
#  'цитирование',
#  'автор',
#  'недопущение',
#  'нарушение',
#  'право',
#  'составление',
#  'акт',
#  'обследование',
#  'лицо',
#  'заключение',
#  'рассмотрение',
#  'суд',
#  'спор',
#  'защита',
#  'представитель',
#  'истец',
#  'иск',
#  'свобода',
#  'интерес',
#  '(орган',
#  'дача',
#  'дело',
#  'ответчик',
#  'случай',
#  'законодательство',
#  'запрос',
#  'сведение',
#  'власть',
#  'выяснение',
#  'мнение',
#  'служба',
#  'медиация',
#  'конфликт',
#  'урегулирование',
#  'существо',
#  'гражданин',
#  'государство',
#  'похищение',
#  'торговля',
#  'человек',
#  'проституция',
#  'порнография',
#  'часть',
#  'полномочие',
#  'подбор',
#  'назначение',
#  'наличие',
#  'разногласие',
#  'экспертиза',
#  'исполнение',
#  'судно',
#  'отобрание',
#  'передача',
#  'мера',
#  'устранение',
#  'препятствие',
#  'родственник',
#  'документация',
#  'переписка',
#  'перечень',
#  'услуга',
#  'восстановление',
#  'привязанность',
#  'описание',
#  'выполнение',
#  'обязанность',
#  'сбор',
#  'обработка',
#  'имя',
#  'фамилия',
#  'указание',
#  'регистрация',
#  'рождение',
#  'отсутствие',
#  'соглашение',
#  'согласие',
#  'установление',
#  'отцовство',
#  'порядок',
#  'объявление',
#  'предъявление',
#  'признание',
#  'брак',
#  'обязательство',
#  'усыновление',
#  'год',
#  'опекун',
#  'осмотр',
#  'освидетельствование',
#  'госпитализация',
#  'стационар',
#  'возражение',
#  'договор',
#  'учёба',
#  'вред',
#  'ущерб',
#  'кинематография',
#  'театр',
#  'цирк',
#  'совершение',
#  'сделка',
#  'имущество',
#  'обмен',
#  'помещение',
#  'собственность',
#  'получение',
#  'раздел',
#  'пользование',
#  'управление',
#  'оформление',
#  'документ',
#  'взыскание',
#  'алименты',
#  'факт',
#  'нуждаемость',
#  'попечение',
#  'отбор',
#  'опека',
#  'попечительство',
#  'угроза',
#  'заявление',
#  'лишение',
#  'ограничение',
#  'утверждение',
#  'план',
#  'устройство',
#  'инициация',
#  'расторжение',
#  'федерация',
#  'предел',
#  'направление',
#  'невозможность',
#  'банк',
#  'срок',
#  'комиссия',
#  'сохранение',
#  'патронат',
#  'журнал',
#  'мать',
#  'личность',
#  'роды',
#  'субъект',
#  'территория',
#  'информирование',
#  'усыновитель',
#  'попечитель',
#  'сайт',
#  'приём',
#  'желание',
#  'выдача',
#  'кандидат',
#  'посещение',
#  'жительство',
#  'отказ',
#  'ознакомление',
#  'ответственность',
#  'опекуном/попечитель',
#  'исключение',
#  'категория',
#  'надзор',
#  '(договор',
#  'обоснованность',
#  'заседание',
#  'гражданство',
#  'выплата',
#  'пособие',
#  'содержание',
#  'вознаграждение',
#  'воспитатель',
#  'проживание',
#  'возвращение',
#  'сохранность',
#  'распоряжение',
#  'проверка',
#  'воспитанник',
#  'контакт',
#  'возврат',
#  'функция',
#  'завершение',
#  'гарантия',
#  '(выдача',
#  'справка',
#  'ходатайство',
#  'консультация',
#  'выпускник',
#  'конфиденциальность',
#  'хранение',
#  'снятие',
#  'отчисление',
#  'учреждение',
#  'обращение',
#  'расходование',
#  'доход',
#  'сумма',
#  'пенсия',
#  'капитал',
#  'отбирание',
#  'возникновение',
#  'отмена',
#  'соблюдение',
#  'течение',
#  'поступление',
#  'неисполнение',
#  'освобождение',
#  'отстранение',
#  '(опека',
#  'сопровождение',
#  'необходимость',
#  'состояние',
#  'путь',
#  'ширина',
#  'колея',
#  'тележка',
#  'отступление',
#  'неисправность',
#  'промер',
#  'режим',
#  'память',
#  'перенос',
#  'компьютер',
#  'расшифровка',
#  'геометрия',
#  'настройка',
#  'характеристика',
#  'допуск',
#  'операция',
#  'работоспособность',
#  'исправность',
#  'калибровка',
#  'участок',
#  'дефектоскоп',
#  'дефект',
#  'повреждение',
#  'рельс',
#  'преобразователь',
#  'классификация',
#  'наладка',
#  'регулировка',
#  'чувствительность',
#  'обслуживание',
#  'узел',
#  'оборудование',
#  'питание',
#  'прибор',
#  'признак',
#  'тупик',
#  'ремонт',
#  'фиксация',
#  'регистратор',
#  'сигнал',
#  'экспресс',
#  'искатель',
#  'запись',
#  'полотно',
#  'график',
#  'измерение',
#  'величина',
#  'износ',
#  'шпала',
#  'маркировка',
#  'замена',
#  'строение',
#  'отчётность',
#  'руководитель',
#  'замечание',
#  'сервер',
#  'база',
#  'ведомость',
#  'носитель',
#  'код',
#  'дефектность',
#  'путеизмерение',
#  'бригада',
#  'распаковка',
#  'монтаж',
#  'станция',
#  'сооружение',
#  'очистка',
#  'водоотведение',
#  'комплектность',
#  'выбраковка',
#  'отчёт',
#  'поставщик',
#  'перемещение',
#  'сортировка',
#  'производство',
#  'положение',
#  'оснащение',
#  'инструкция',
#  'разметка',
#  'состыковка',
#  'трубопровод',
#  'испытание',
#  'точка',
#  'обкатка',
#  'нагрузка',
#  'сравнение',
#  'последовательность',
#  'член',
#  'распределение',
#  'объём',
#  'монтажник',
#  'машина',
#  'механизм',
#  'площадка',
#  'инвентарь',
#  'заявка',
#  'дата',
#  'поверка',
#  'координация',
#  'внедрение',
#  'функционирование',
#  'менеджмент',
#  'охрана',
#  'чертёж',
#  'конструкция',
#  'соединение',
#  'серия',
#  'спецификация',
#  'металлопрокат',
#  'комплект',
#  'нормоконтроль',
#  'внесение',
#  'экземпляр',
#  'согласование',
#  'компонент',
#  'детализация',
#  'здание',
#  'основание',
#  'строительство',
#  'разработчик',
#  'коллектив',
#  'документирование',
#  'район',
#  'возведение',
#  'воздействие',
#  'расчёт',
#  'схема',
#  'комплекс',
#  'сечение',
#  'стык',
#  'прохождение',
#  'каркас',
#  'публикация',
#  'выпуск',
#  'концепция',
#  'графика',
#  'технико',
#  'подразделение',
#  'этап',
#  'цикл',
#  'коллизия',
#  'отклонение',
#  'подлежащее',
#  'включение',
#  'эксплуатация',
#  'расположение',
#  'профиль',
#  'трасса',
#  'изыскание',
#  'изделие',
#  'прокладка',
#  'заказчик',
#  'принадлежность',
#  'обзор',
#  'отзыв',
#  'эскиз',
#  'обоснование',
#  'санация',
#  'ликвидация',
#  'стандартизация',
#  'санитария',
#  'утилизация',
#  'раствор',
#  'начало',
#  'окончание',
#  'целое',
#  'критерий',
#  'исполнитель',
#  'исследование',
#  'приёмка',
#  'изготовление',
#  'изготовитель',
#  'аналог',
#  'выработка',
#  '(тактико',
#  'поставка',
#  'комплектование',
#  'автоматизация',
#  '(разработка',
#  'подсистема',
#  'ввод',
#  'своевременность',
#  'подача',
#  'патент',
#  'изобретение',
#  'обход',
#  'арматура',
#  'автоматика',
#  'опора',
#  'фундамент',
#  'поверхность',
#  'аппарат',
#  'давление',
#  'насос',
#  'утечка',
#  'газ',
#  'конденсат',
#  'жидкость',
#  'целостность',
#  'вентиляция',
#  '(вентилятор',
#  'воздуховод',
#  'клапан',
#  'шум',
#  'заграждение',
#  'приспособление',
#  'загазованность',
#  'воздух',
#  'переработка',
#  '(оператор',
#  'сверка',
#  'показание',
#  'кипиа',
#  'заполнение',
#  'лист',
#  'перекачивание',
#  'затаривание',
#  'смазка',
#  'масло',
#  'склад',
#  'ёмкость',
#  'продувка',
#  'чистка',
#  'стекло',
#  'колонка',
#  '(буйков',
#  'манометр',
#  'фильтр',
#  'реагент',
#  'подтягивание',
#  'набивка',
#  'сальников',
#  'уплотнение',
#  'загрязнение',
#  'компрессор',
#  'переключение',
#  'руководство',
#  'оператор',
#  'квалификация',
#  'сырьё',
#  'полупродукт',
#  'продукт',
#  'ям',
#  'резервуар',
#  'расход',
#  'количество',
#  'продукция',
#  'отслеживание',
#  'горение',
#  'топка',
#  'печь',
#  'проба',
#  'закачка',
#  'засыпка',
#  'слив',
#  'пожаротушение',
#  'газоанализатор',
#  'ограждение',
#  'знак',
#  'отключение',
#  'заглушка',
#  'сброс',
#  'факел',
#  'пропарка',
#  'промывка',
#  'откачка',
#  'вскрытие',
#  'перепаковка',
#  'пара',
#  'линия',
#  'аппаратура',
#  'загрузка',
#  'выгрузка',
#  'катализатор',
#  'в/из',
#  '(сетка',
#  'демонтаж',
#  'оребрение',
#  'охлаждение',
#  'погрузка',
#  'техника',
#  'опрессовка',
#  'сборка',
#  'блок',
#  'отделение',
#  'сдача',
#  'смена',
#  'сигнализация',
#  'герметичность',
#  'вода',
#  'пенообразователь',
#  'смеситель',
#  'инжектор',
#  'пожарный',
#  'пеногенератор',
#  'баллон',
#  'вещество',
#  'форсунка',
#  'распылитель',
#  'водяной',
#  'рукав',
#  'пуск',
#  'остановка',
#  'вывод',
#  'рабочий',
#  'пульт',
#  'диспетчер',
#  'причина',
#  'подсчёт',
#  'баланс',
#  'движение',
#  'предупреждение',
#  'авария',
#  'расстановка',
#  'локализация',
#  'опасность',
#  'вытеснение',
#  '(полупродукт',
#  'доведение',
#  'значение',
#  'регламент',
#  'огнев',
#  'инструктирование',
#  'тарировка',
#  'камера',
#  'ревизия',
#  'топливо',
#  'электроэнергия',
#  'реактор',
#  'адсорбер',
#  'конвертор',
#  'неполадка',
#  'сложность',
#  'деталь',
#  'покрытие',
#  'теплоизоляция',
#  'протяжка',
#  'гидросистема',
#  'гидропривод',
#  'шаров',
#  'обвязка',
#  '(аво',
#  'слесарь',
#  'агрегат',
#  'крышка',
#  'сосуд',
#  'лубрикатор',
#  'сальник',
#  'маслоотражатель',
#  'подшипник',
#  'цилиндр',
#  'маслоблок',
#  'корпус',
#  'отложение',
#  'теплообменник',
#  '(шурфовка',
#  'разборка',
#  'втулка',
#  'вал',
#  'квалитет',
#  'шпиндель',
#  'поток',
#  'поднятие',
#  'пропуск',
#  'хранилище',
#  'секция',
#  'аво',
#  'диаметр',
#  'мпа',
#  'консервация',
#  'электростанция',
#  'турбина',
#  'нагнетатель',
#  'сгорание',
#  'завод',
#  'закрытие',
#  'лаз',
#  'притирка',
#  'зазор',
#  'центровка',
#  'вентилятор',
#  'двигатель',
#  'гидроиспытание',
#  'маслобак',
#  'отвод',
#  '(пылеуловитель',
#  'маслосистема',
#  '(ёмкость',
#  'слива',
#  'маслопровод',
#  '(регулятор',
#  'осушка',
#  'подогреватель',
#  'подключение',
#  'отсек',
#  'щит',
#  '(резерв',
#  'реконструкция',
#  'наряд',
#  'останов',
#  'теплосъём',
#  'жалюзи',
#  'включением/отключение',
#  'температура',
#  'выход',
#  'срабатывание',
#  'электроустановка',
#  'напряжение',
#  'обнаружение',
#  'удаление',
#  'продолжительность',
#  'энергоаудитор',
#  'размещение',
#  'электропотребитель',
#  'протяжённость',
#  'электропередача',
#  'энергия',
#  'предложение',
#  'электрооборудование',
#  'электробезопасность',
#  'персонал',
#  'потеря',
#  'потребление',
#  'затрата',
#  'окупаемость',
#  'паспорт',
#  'теплопотребитель',
#  'теплопотребление',
#  'газоснабжение',
#  'отопление',
#  'кондиционирование',
#  'полнота',
#  'энергопотребление',
#  'корректность',
#  'единица',
#  'энергоресурсы',
#  'энергоэффективность',
#  'министерство',
#  'выезд',
#  'мощность',
#  'автотранспорт',
#  'стоимость',
#  'местоположение',
#  'вызов',
#  'интервал',
#  'риск',
#  'разбивка',
#  'местность',
#  'закрепление',
#  'упреждение',
#  'последствие',
#  'изыскатель',
#  'проектировщик',
#  'инструктаж',
#  'прекращение',
#  'продолжение',
#  'протокол',
#  'транспорт',
#  'механизация',
#  'разгрузка',
#  'заправка',
#  'следование',
#  'приготовление',
#  'доставка',
#  'снабжение',
#  'отображение',
#  'некомплектность',
#  'инстанция',
#  'натура',
#  'вынос',
#  'разрез',
#  'створ',
#  'шурфление',
#  'владелец',
#  'землеотвод',
#  'уведомление',
#  'несоответствие',
#  'мастер',
#  'приведение',
#  'подряд',
#  'фактор',
#  'производительность',
#  'оптимизация',
#  'снижение',
#  'издержка',
#  ...]

# %% [markdown]
# Импортируем данные о курсах `teach-in.ru`

# %%
teachin_df = pd.read_csv('teach_in.csv', sep=';')
teachin_df.head()
# Out:
#                                       Ссылка на курс Количество лекций  \
# 0  https://teach-in.ru//course/one-hundred-hours-...         29 лекций
# 1  https://teach-in.ru//course/one-hundred-hours-...         11 лекций
# 2  https://teach-in.ru//course/basics-of-radioche...         12 лекций
# 3  https://teach-in.ru//course/basics-of-radioche...         10 лекций
# 4       https://teach-in.ru//course/entagled-diffury          4 лекции
#
#                                       Название курса   Категория  \
# 0  100 часов школьной биологии. Анатомия и физиол...    Биология
# 1        100 часов школьной биологии. Общая биология    Биология
# 2                   Basics of radiochemistry. Лекции       Химия
# 3                 Basics of radiochemistry. Семинары       Химия
# 4               ENTANGLED Дифференциальные уравнения  Математика
#
#    Количество просмотров                         Автор  \
# 0                    1.0  Дубынин Вячеслав Альбертович
# 1                    NaN  Дубынин Вячеслав Альбертович
# 2                    NaN   Петров Владимир Геннадьевич
# 3                    NaN   Петров Владимир Геннадьевич
# 4                    NaN    Гайер Алексей Вячеславович
#
#                            Ссылка на автора  \
# 0     https://teach-in.ru//lecturer/dybinin
# 1     https://teach-in.ru//lecturer/dybinin
# 2  https://teach-in.ru//lecturer/petrov-v-g
# 3  https://teach-in.ru//lecturer/petrov-v-g
# 4    https://teach-in.ru//lecturer/gaier-av
#
#                                          Видеолекции  \
# 0  /lecture/2021-07-30-Dubynin Вступительное слов...
# 1  /lecture/2021-10-11-Dubynin Лекция 1. Вода и м...
# 2  /lecture/2021-09-10-Petrov-2 Лекция 1. Introdu...
# 3  /lecture/2021-09-10-Petrov-1 Семинар 1. Types ...
# 4  /lecture/2021-12-21-Gaier Семинар 1. Дифференц...
#
#                                              О курсе
# 0  ,Список всех тем лекций, , Вступительное слово...
# 1  ,Список всех тем лекций,Лекция 1. Вода и минер...
# 2  ,Список всех тем лекций,Лекция 1. Introduction...
# 3  ,Список всех тем лекций,Семинар 1. Types of ra...
# 4  ,Список всех тем лекций,Семинар 1. Дифференциа...

# %% [markdown]
# Оставим только те данные, которые нам понадобятся в будущем

# %%
teachin_df = teachin_df[['Название курса', 'Ссылка на курс', 'О курсе']]
teachin_df
# Out:
#                                         Название курса  \
# 0    100 часов школьной биологии. Анатомия и физиол...
# 1          100 часов школьной биологии. Общая биология
# 2                     Basics of radiochemistry. Лекции
# 3                   Basics of radiochemistry. Семинары
# 4                 ENTANGLED Дифференциальные уравнения
# ..                                                 ...
# 538                    Элементы теории чисел. Семинары
# 539  Элементы топологии и симплектической геометрии...
# 540  Элементы топологии и симплектической геометрии...
# 541       Эллиптические операторы и теорема об индексе
# 542                                        Эмбриология
#
#                                         Ссылка на курс  \
# 0    https://teach-in.ru//course/one-hundred-hours-...
# 1    https://teach-in.ru//course/one-hundred-hours-...
# 2    https://teach-in.ru//course/basics-of-radioche...
# 3    https://teach-in.ru//course/basics-of-radioche...
# 4         https://teach-in.ru//course/entagled-diffury
# ..                                                 ...
# 538  https://teach-in.ru//course/elements-of-number...
# 539  https://teach-in.ru//course/elements-of-topolo...
# 540  https://teach-in.ru//course/elements-of-topolo...
# 541  https://teach-in.ru//course/elliptic-operators...
# 542  https://teach-in.ru//course/embryology-golyche...
#
#                                                О курсе
# 0    ,Список всех тем лекций, , Вступительное слово...
# 1    ,Список всех тем лекций,Лекция 1. Вода и минер...
# 2    ,Список всех тем лекций,Лекция 1. Introduction...
# 3    ,Список всех тем лекций,Семинар 1. Types of ra...
# 4    ,Список всех тем лекций,Семинар 1. Дифференциа...
# ..                                                 ...
# 538  ,Семинары по базовому курсу теории чисел на 1 ...
# 539  ,Спецкурс для студентов 1–6 курсов,Список всех...
# 540  ,Спецкурс для студентов 1–6 курсов,Список всех...
# 541  ,Основная цель курса – познакомить слушателей ...
# 542  ,Список всех тем лекций,Лекция 1. Введение.,Ле...
#
# [543 rows x 3 columns]

# %% [markdown]
# Создадим список ключевых слов для каждого курса

# %%
teachin_df['course_keys'] = teachin_df['О курсе'].apply(get_keys)
teachin_df
# Out:
#                                         Название курса  \
# 0    100 часов школьной биологии. Анатомия и физиол...
# 1          100 часов школьной биологии. Общая биология
# 2                     Basics of radiochemistry. Лекции
# 3                   Basics of radiochemistry. Семинары
# 4                 ENTANGLED Дифференциальные уравнения
# ..                                                 ...
# 538                    Элементы теории чисел. Семинары
# 539  Элементы топологии и симплектической геометрии...
# 540  Элементы топологии и симплектической геометрии...
# 541       Эллиптические операторы и теорема об индексе
# 542                                        Эмбриология
#
#                                         Ссылка на курс  \
# 0    https://teach-in.ru//course/one-hundred-hours-...
# 1    https://teach-in.ru//course/one-hundred-hours-...
# 2    https://teach-in.ru//course/basics-of-radioche...
# 3    https://teach-in.ru//course/basics-of-radioche...
# 4         https://teach-in.ru//course/entagled-diffury
# ..                                                 ...
# 538  https://teach-in.ru//course/elements-of-number...
# 539  https://teach-in.ru//course/elements-of-topolo...
# 540  https://teach-in.ru//course/elements-of-topolo...
# 541  https://teach-in.ru//course/elliptic-operators...
# 542  https://teach-in.ru//course/embryology-golyche...
#
#                                                О курсе  \
# 0    ,Список всех тем лекций, , Вступительное слово...
# 1    ,Список всех тем лекций,Лекция 1. Вода и минер...
# 2    ,Список всех тем лекций,Лекция 1. Introduction...
# 3    ,Список всех тем лекций,Семинар 1. Types of ra...
# 4    ,Список всех тем лекций,Семинар 1. Дифференциа...
# ..                                                 ...
# 538  ,Семинары по базовому курсу теории чисел на 1 ...
# 539  ,Спецкурс для студентов 1–6 курсов,Список всех...
# 540  ,Спецкурс для студентов 1–6 курсов,Список всех...
# 541  ,Основная цель курса – познакомить слушателей ...
# 542  ,Список всех тем лекций,Лекция 1. Введение.,Ле...
#
#                                            course_keys
# 0    [список, лекция, слово, курс, сто, час, биолог...
# 1    [список, лекция, вода, соль, соединение, принц...
# 2                                     [список, лекция]
# 3                            [список, лекция, семинар]
# 4    [список, лекция, семинар, уравнение, го, поряд...
# ..                                                 ...
# 538  [семинар, курс, теория, число, список, лекция,...
# 539  [спецкурс, студент, курс, список, лекция, крив...
# 540  [спецкурс, студент, курс, список, лекция, теор...
# 541  [цель, слушателей с, понятие, метод, теория, ф...
# 542  [список, лекция, введение, оогенез, сперматоге...
#
# [543 rows x 4 columns]

# %% [markdown]
# Создадим датафрейм, который будем использовать в рекомендательной системе. Объектами будут ключевые слова, полученные из трудовых действий. Им будем рекомендовать курсы `teach-in.ru`

# %%
df = pd.DataFrame(index=lab_actions_keys, columns=teachin_df['Название курса'])
df
# Out:
# Название курса       100 часов школьной биологии. Анатомия и физиология человека  \
# разработка                                                          NaN
# реализация                                                          NaN
# программа                                                           NaN
# дисциплина                                                          NaN
# рамка                                                               NaN
# ...                                                                 ...
# линь                                                                NaN
# динамик                                                             NaN
# патч                                                                NaN
# клеммов                                                             NaN
# переконфигурирование                                                NaN
#
# Название курса       100 часов школьной биологии. Общая биология  \
# разработка                                                   NaN
# реализация                                                   NaN
# программа                                                    NaN
# дисциплина                                                   NaN
# рамка                                                        NaN
# ...                                                          ...
# линь                                                         NaN
# динамик                                                      NaN
# патч                                                         NaN
# клеммов                                                      NaN
# переконфигурирование                                         NaN
#
# Название курса       Basics of radiochemistry. Лекции  \
# разработка                                        NaN
# реализация                                        NaN
# программа                                         NaN
# дисциплина                                        NaN
# рамка                                             NaN
# ...                                               ...
# линь                                              NaN
# динамик                                           NaN
# патч                                              NaN
# клеммов                                           NaN
# переконфигурирование                              NaN
#
# Название курса       Basics of radiochemistry. Семинары  \
# разработка                                          NaN
# реализация                                          NaN
# программа                                           NaN
# дисциплина                                          NaN
# рамка                                               NaN
# ...                                                 ...
# линь                                                NaN
# динамик                                             NaN
# патч                                                NaN
# клеммов                                             NaN
# переконфигурирование                                NaN
#
# Название курса       ENTANGLED Дифференциальные уравнения  \
# разработка                                            NaN
# реализация                                            NaN
# программа                                             NaN
# дисциплина                                            NaN
# рамка                                                 NaN
# ...                                                   ...
# линь                                                  NaN
# динамик                                               NaN
# патч                                                  NaN
# клеммов                                               NaN
# переконфигурирование                                  NaN
#
# Название курса       ENTANGLED Квантовая теория  \
# разработка                                  NaN
# реализация                                  NaN
# программа                                   NaN
# дисциплина                                  NaN
# рамка                                       NaN
# ...                                         ...
# линь                                        NaN
# динамик                                     NaN
# патч                                        NaN
# клеммов                                     NaN
# переконфигурирование                        NaN
#
# Название курса       ENTANGLED Математический анализ. 2 семестр  \
# разработка                                                  NaN
# реализация                                                  NaN
# программа                                                   NaN
# дисциплина                                                  NaN
# рамка                                                       NaN
# ...                                                         ...
# линь                                                        NaN
# динамик                                                     NaN
# патч                                                        NaN
# клеммов                                                     NaN
# переконфигурирование                                        NaN
#
# Название курса       Python и облачные вычисления в науке  \
# разработка                                            NaN
# реализация                                            NaN
# программа                                             NaN
# дисциплина                                            NaN
# рамка                                                 NaN
# ...                                                   ...
# линь                                                  NaN
# динамик                                               NaN
# патч                                                  NaN
# клеммов                                               NaN
# переконфигурирование                                  NaN
#
# Название курса       Автоморфизмы аффинных алгебраических многообразий  \
# разработка                                                         NaN
# реализация                                                         NaN
# программа                                                          NaN
# дисциплина                                                         NaN
# рамка                                                              NaN
# ...                                                                ...
# линь                                                               NaN
# динамик                                                            NaN
# патч                                                               NaN
# клеммов                                                            NaN
# переконфигурирование                                               NaN
#
# Название курса       Алгебра. Семинары. Часть 1  ...  \
# разработка                                  NaN  ...
# реализация                                  NaN  ...
# программа                                   NaN  ...
# дисциплина                                  NaN  ...
# рамка                                       NaN  ...
# ...                                         ...  ...
# линь                                        NaN  ...
# динамик                                     NaN  ...
# патч                                        NaN  ...
# клеммов                                     NaN  ...
# переконфигурирование                        NaN  ...
#
# Название курса       Электромагнетизм. Семинары Элементы строения вещества  \
# разработка                                  NaN                        NaN
# реализация                                  NaN                        NaN
# программа                                   NaN                        NaN
# дисциплина                                  NaN                        NaN
# рамка                                       NaN                        NaN
# ...                                         ...                        ...
# линь                                        NaN                        NaN
# динамик                                     NaN                        NaN
# патч                                        NaN                        NaN
# клеммов                                     NaN                        NaN
# переконфигурирование                        NaN                        NaN
#
# Название курса       Элементы теории гомологий Элементы теории чисел  \
# разработка                                 NaN                   NaN
# реализация                                 NaN                   NaN
# программа                                  NaN                   NaN
# дисциплина                                 NaN                   NaN
# рамка                                      NaN                   NaN
# ...                                        ...                   ...
# линь                                       NaN                   NaN
# динамик                                    NaN                   NaN
# патч                                       NaN                   NaN
# клеммов                                    NaN                   NaN
# переконфигурирование                       NaN                   NaN
#
# Название курса       Элементы теории чисел Элементы теории чисел. Семинары  \
# разработка                             NaN                             NaN
# реализация                             NaN                             NaN
# программа                              NaN                             NaN
# дисциплина                             NaN                             NaN
# рамка                                  NaN                             NaN
# ...                                    ...                             ...
# линь                                   NaN                             NaN
# динамик                                NaN                             NaN
# патч                                   NaN                             NaN
# клеммов                                NaN                             NaN
# переконфигурирование                   NaN                             NaN
#
# Название курса       Элементы топологии и симплектической геометрии. Часть 1  \
# разработка                                                          NaN
# реализация                                                          NaN
# программа                                                           NaN
# дисциплина                                                          NaN
# рамка                                                               NaN
# ...                                                                 ...
# линь                                                                NaN
# динамик                                                             NaN
# патч                                                                NaN
# клеммов                                                             NaN
# переконфигурирование                                                NaN
#
# Название курса       Элементы топологии и симплектической геометрии. Часть 2  \
# разработка                                                          NaN
# реализация                                                          NaN
# программа                                                           NaN
# дисциплина                                                          NaN
# рамка                                                               NaN
# ...                                                                 ...
# линь                                                                NaN
# динамик                                                             NaN
# патч                                                                NaN
# клеммов                                                             NaN
# переконфигурирование                                                NaN
#
# Название курса       Эллиптические операторы и теорема об индексе Эмбриология
# разработка                                                    NaN         NaN
# реализация                                                    NaN         NaN
# программа                                                     NaN         NaN
# дисциплина                                                    NaN         NaN
# рамка                                                         NaN         NaN
# ...                                                           ...         ...
# линь                                                          NaN         NaN
# динамик                                                       NaN         NaN
# патч                                                          NaN         NaN
# клеммов                                                       NaN         NaN
# переконфигурирование                                          NaN         NaN
#
# [10539 rows x 543 columns]

# %%
for key in lab_actions_keys:
    vals = []
    interaction_list = []
    for course in teachin_df['Название курса']:
        vals.append(key in teachin_df.loc[teachin_df['Название курса']==course,'course_keys'].values[0])
    df.loc[key] = vals

# %%
df = df.astype(int)
df
# Out:
# Название курса        100 часов школьной биологии. Анатомия и физиология человека  \
# разработка                                                            0
# реализация                                                            0
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
# Название курса        100 часов школьной биологии. Общая биология  \
# разработка                                                      0
# реализация                                                      0
# программа                                                       0
# дисциплина                                                      0
# рамка                                                           0
# ...                                                           ...
# линь                                                            0
# динамик                                                         0
# патч                                                            0
# клеммов                                                         0
# переконфигурирование                                            0
#
# Название курса        Basics of radiochemistry. Лекции  \
# разработка                                           0
# реализация                                           0
# программа                                            0
# дисциплина                                           0
# рамка                                                0
# ...                                                ...
# линь                                                 0
# динамик                                              0
# патч                                                 0
# клеммов                                              0
# переконфигурирование                                 0
#
# Название курса        Basics of radiochemistry. Семинары  \
# разработка                                             0
# реализация                                             0
# программа                                              0
# дисциплина                                             0
# рамка                                                  0
# ...                                                  ...
# линь                                                   0
# динамик                                                0
# патч                                                   0
# клеммов                                                0
# переконфигурирование                                   0
#
# Название курса        ENTANGLED Дифференциальные уравнения  \
# разработка                                               0
# реализация                                               0
# программа                                                0
# дисциплина                                               0
# рамка                                                    0
# ...                                                    ...
# линь                                                     0
# динамик                                                  0
# патч                                                     0
# клеммов                                                  0
# переконфигурирование                                     0
#
# Название курса        ENTANGLED Квантовая теория  \
# разработка                                     0
# реализация                                     0
# программа                                      0
# дисциплина                                     0
# рамка                                          0
# ...                                          ...
# линь                                           0
# динамик                                        0
# патч                                           0
# клеммов                                        0
# переконфигурирование                           0
#
# Название курса        ENTANGLED Математический анализ. 2 семестр  \
# разработка                                                     0
# реализация                                                     0
# программа                                                      0
# дисциплина                                                     0
# рамка                                                          0
# ...                                                          ...
# линь                                                           0
# динамик                                                        0
# патч                                                           0
# клеммов                                                        0
# переконфигурирование                                           0
#
# Название курса        Python и облачные вычисления в науке  \
# разработка                                               0
# реализация                                               0
# программа                                                1
# дисциплина                                               0
# рамка                                                    0
# ...                                                    ...
# линь                                                     0
# динамик                                                  0
# патч                                                     0
# клеммов                                                  0
# переконфигурирование                                     0
#
# Название курса        Автоморфизмы аффинных алгебраических многообразий  \
# разработка                                                            0
# реализация                                                            0
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
# Название курса        Алгебра. Семинары. Часть 1  ...  \
# разработка                                     0  ...
# реализация                                     0  ...
# программа                                      0  ...
# дисциплина                                     0  ...
# рамка                                          0  ...
# ...                                          ...  ...
# линь                                           0  ...
# динамик                                        0  ...
# патч                                           0  ...
# клеммов                                        0  ...
# переконфигурирование                           0  ...
#
# Название курса        Электромагнетизм. Семинары  Элементы строения вещества  \
# разработка                                     0                           0
# реализация                                     0                           0
# программа                                      0                           0
# дисциплина                                     0                           1
# рамка                                          1                           0
# ...                                          ...                         ...
# линь                                           0                           0
# динамик                                        0                           0
# патч                                           0                           0
# клеммов                                        0                           0
# переконфигурирование                           0                           0
#
# Название курса        Элементы теории гомологий  Элементы теории чисел  \
# разработка                                    0                      0
# реализация                                    0                      0
# программа                                     0                      1
# дисциплина                                    0                      0
# рамка                                         0                      0
# ...                                         ...                    ...
# линь                                          0                      0
# динамик                                       0                      0
# патч                                          0                      0
# клеммов                                       0                      0
# переконфигурирование                          0                      0
#
# Название курса        Элементы теории чисел  Элементы теории чисел. Семинары  \
# разработка                                0                                0
# реализация                                0                                0
# программа                                 1                                0
# дисциплина                                0                                0
# рамка                                     0                                0
# ...                                     ...                              ...
# линь                                      0                                0
# динамик                                   0                                0
# патч                                      0                                0
# клеммов                                   0                                0
# переконфигурирование                      0                                0
#
# Название курса        Элементы топологии и симплектической геометрии. Часть 1  \
# разработка                                                            0
# реализация                                                            1
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
# Название курса        Элементы топологии и симплектической геометрии. Часть 2  \
# разработка                                                            0
# реализация                                                            0
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
# Название курса        Эллиптические операторы и теорема об индексе  \
# разработка                                                       0
# реализация                                                       0
# программа                                                        0
# дисциплина                                                       0
# рамка                                                            0
# ...                                                            ...
# линь                                                             0
# динамик                                                          0
# патч                                                             0
# клеммов                                                          0
# переконфигурирование                                             0
#
# Название курса        Эмбриология
# разработка                      0
# реализация                      0
# программа                       0
# дисциплина                      0
# рамка                           0
# ...                           ...
# линь                            0
# динамик                         0
# патч                            0
# клеммов                         0
# переконфигурирование            0
#
# [10539 rows x 543 columns]

# %%
df = pd.read_csv('df.csv', index_col=0)
df
# Out:
#                       100 часов школьной биологии. Анатомия и физиология человека  \
# разработка                                                            0
# реализация                                                            0
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
#                       100 часов школьной биологии. Общая биология  \
# разработка                                                      0
# реализация                                                      0
# программа                                                       0
# дисциплина                                                      0
# рамка                                                           0
# ...                                                           ...
# линь                                                            0
# динамик                                                         0
# патч                                                            0
# клеммов                                                         0
# переконфигурирование                                            0
#
#                       Basics of radiochemistry. Лекции  \
# разработка                                           0
# реализация                                           0
# программа                                            0
# дисциплина                                           0
# рамка                                                0
# ...                                                ...
# линь                                                 0
# динамик                                              0
# патч                                                 0
# клеммов                                              0
# переконфигурирование                                 0
#
#                       Basics of radiochemistry. Семинары  \
# разработка                                             0
# реализация                                             0
# программа                                              0
# дисциплина                                             0
# рамка                                                  0
# ...                                                  ...
# линь                                                   0
# динамик                                                0
# патч                                                   0
# клеммов                                                0
# переконфигурирование                                   0
#
#                       ENTANGLED Дифференциальные уравнения  \
# разработка                                               0
# реализация                                               0
# программа                                                0
# дисциплина                                               0
# рамка                                                    0
# ...                                                    ...
# линь                                                     0
# динамик                                                  0
# патч                                                     0
# клеммов                                                  0
# переконфигурирование                                     0
#
#                       ENTANGLED Квантовая теория  \
# разработка                                     0
# реализация                                     0
# программа                                      0
# дисциплина                                     0
# рамка                                          0
# ...                                          ...
# линь                                           0
# динамик                                        0
# патч                                           0
# клеммов                                        0
# переконфигурирование                           0
#
#                       ENTANGLED Математический анализ. 2 семестр  \
# разработка                                                     0
# реализация                                                     0
# программа                                                      0
# дисциплина                                                     0
# рамка                                                          0
# ...                                                          ...
# линь                                                           0
# динамик                                                        0
# патч                                                           0
# клеммов                                                        0
# переконфигурирование                                           0
#
#                       Python и облачные вычисления в науке  \
# разработка                                               0
# реализация                                               0
# программа                                                1
# дисциплина                                               0
# рамка                                                    0
# ...                                                    ...
# линь                                                     0
# динамик                                                  0
# патч                                                     0
# клеммов                                                  0
# переконфигурирование                                     0
#
#                       Автоморфизмы аффинных алгебраических многообразий  \
# разработка                                                            0
# реализация                                                            0
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
#                       Алгебра. Семинары. Часть 1  ...  \
# разработка                                     0  ...
# реализация                                     0  ...
# программа                                      0  ...
# дисциплина                                     0  ...
# рамка                                          0  ...
# ...                                          ...  ...
# линь                                           0  ...
# динамик                                        0  ...
# патч                                           0  ...
# клеммов                                        0  ...
# переконфигурирование                           0  ...
#
#                       Электромагнетизм. Семинары  Элементы строения вещества  \
# разработка                                     0                           0
# реализация                                     0                           0
# программа                                      0                           0
# дисциплина                                     0                           1
# рамка                                          1                           0
# ...                                          ...                         ...
# линь                                           0                           0
# динамик                                        0                           0
# патч                                           0                           0
# клеммов                                        0                           0
# переконфигурирование                           0                           0
#
#                       Элементы теории гомологий  Элементы теории чисел  \
# разработка                                    0                      0
# реализация                                    0                      0
# программа                                     0                      1
# дисциплина                                    0                      0
# рамка                                         0                      0
# ...                                         ...                    ...
# линь                                          0                      0
# динамик                                       0                      0
# патч                                          0                      0
# клеммов                                       0                      0
# переконфигурирование                          0                      0
#
#                       Элементы теории чисел.1  \
# разработка                                  0
# реализация                                  0
# программа                                   1
# дисциплина                                  0
# рамка                                       0
# ...                                       ...
# линь                                        0
# динамик                                     0
# патч                                        0
# клеммов                                     0
# переконфигурирование                        0
#
#                       Элементы теории чисел. Семинары  \
# разработка                                          0
# реализация                                          0
# программа                                           0
# дисциплина                                          0
# рамка                                               0
# ...                                               ...
# линь                                                0
# динамик                                             0
# патч                                                0
# клеммов                                             0
# переконфигурирование                                0
#
#                       Элементы топологии и симплектической геометрии. Часть 1  \
# разработка                                                            0
# реализация                                                            1
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
#                       Элементы топологии и симплектической геометрии. Часть 2  \
# разработка                                                            0
# реализация                                                            0
# программа                                                             0
# дисциплина                                                            0
# рамка                                                                 0
# ...                                                                 ...
# линь                                                                  0
# динамик                                                               0
# патч                                                                  0
# клеммов                                                               0
# переконфигурирование                                                  0
#
#                       Эллиптические операторы и теорема об индексе  \
# разработка                                                       0
# реализация                                                       0
# программа                                                        0
# дисциплина                                                       0
# рамка                                                            0
# ...                                                            ...
# линь                                                             0
# динамик                                                          0
# патч                                                             0
# клеммов                                                          0
# переконфигурирование                                             0
#
#                       Эмбриология
# разработка                      0
# реализация                      0
# программа                       0
# дисциплина                      0
# рамка                           0
# ...                           ...
# линь                            0
# динамик                         0
# патч                            0
# клеммов                         0
# переконфигурирование            0
#
# [10539 rows x 543 columns]

# %% [markdown]
# Обучим модель рекомендательной системы. Будем использовать библиотеку <a href='https://github.com/lyst/lightfm'>LightFM</a>

# %%
model = LightFM(loss='warp-kos')
model.fit(sparse.coo_matrix(df))

# %% [markdown]
# Получим 3 лучшие рекомендации для объекта.

# %%
item = 20 # индекс объекта, для которого получаем рекомендации
preds = model.predict(item, list(range(len(df.columns))))
preds = pd.Series(preds).sort_values()
preds = preds ** 2
preds = ((preds-min(preds))*100/(max(preds)-min(preds))).head(3) # берем только 3 лучшие рекомендации
preds
# Out:
# 381    100.000000
# 331     97.257538
# 117     96.880913
# dtype: float32

# %%
print('Ключевое слово:', df.index[item])
print('Рекомедованные курсы:')
result_df = pd.DataFrame(columns=['№ п/п', 'Курсы', 'Балл', 'Ссылка'])
for i, course in enumerate(zip(df.columns[preds.index], preds.values)):
    result_df.loc[len(result_df)] = [i+1, course[0], int(course[1]), teachin_df.iloc[preds.index[i], 1]]
result_df
# Out:
# Ключевое слово: занятие
# Рекомедованные курсы:
#    № п/п                                              Курсы  Балл  \
# 0      1  Решение прикладных задач с помощью программиро...   100
# 1      2              Общая физика для школьников. Механика    97
# 2      3           Дифференциальная геометрия и топология.2    96
#
#                                               Ссылка
# 0  https://teach-in.ru//course/solving-applied-pr...
# 1  https://teach-in.ru//course/general-physics-fo...
# 2  https://teach-in.ru//course/differential-geome...
